# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelCaballero/BME/blob/main/mfia/proyecto01_python_basico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicios básicos de Python
#
# Instrucciones:
#
# 1. Lee cada enunciado.
# 2. Escribe tu solución en la celda de código correspondiente. Si no se te ocurre revisa los notebooks que hemos visto o pregunta a la IA, pero trata de entender el código, modifícalo, etc. hazlo "tuyo".
# 3. Ejecuta la celda.
# 4. Comprueba que el resultado tiene sentido.
#
# No hace falta usar nada que no hayamos visto en clase (`input()`, listas, bucles ni condicionales)

# %% [markdown]
# ## Ejercicio 1. Cierre BBVA
#
# Crear una variable `cierre`que tome el valor de cierre de BBVA (digamos 18,81)
#
# Mostrar el resultado con `print`.
#
# Nota: recordar que en Python se utiliza pubnto (.) como separador de decimales

# %%
# escribe la solución en las dos líneas siguientes

# %% [markdown]
# ## Ejercicio 2. Edad el año que viene
#
# Crea una variable `edad` con tu edad actual.
#
# Después crea otra variable llamada `edad_siguiente` que guarde tu edad dentro de un año.
#
# Muestra el resultado con `print`.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 3. Presentación personal
#
# Crea tres variables:
#
# - `nombre`
# - `edad`
# - `ciudad`
#
# Después muestra una frase como esta:
#
# `Me llamo Luis, tengo 20 años y vivo en Madrid.`

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 4. Suma de dos números
#
# Crea dos variables, `a` y `b`, con dos números cualquiera.
#
# Crea una variable `suma` que guarde la suma de ambos.
#
# Muestra el resultado por pantalla.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 5. Cambio de valor de una variable
#
# Crea una variable `puntos` con valor `10`.
#
# Después súmale `5` puntos y guarda el nuevo resultado en la misma variable `puntos`.
#
# Muestra el valor final.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 6. Precio total de una compra
#
# Crea estas variables:
#
# - `precio_producto`
# - `unidades`
#
# Calcula el precio total de la compra y muéstralo por pantalla.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 7. Precio con IVA
#
# Crea una variable `precio_sin_iva`.
#
# Calcula el precio con un IVA del 21%.
#
# Pista: para sumar un 21%, puedes multiplicar por `1.21`.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 8. Conversión de euros a céntimos
#
# Crea una variable `euros`.
#
# Muestra cuántos céntimos son esos euros y muéstralos con print

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 9. Área de un rectángulo
#
# Crea dos variables:
#
# - `base`
# - `altura`
#
# Calcula el área del rectángulo.
#
# Recuerda:
#
# `área = base * altura`

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 10. Media de tres notas
#
# Crea tres variables:
#
# - `nota1`
# - `nota2`
# - `nota3`
#
# Calcula la media de las tres notas y muéstrala por pantalla.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 11. Función de saludo
#
# Escribe una función llamada `saludar`.
#
# La función debe recibir un parámetro llamado `nombre` y mostrar un saludo.
#
# Ejemplo para probar:
#
# ```python
# saludar("Ana")
# ```
#
# Debería mostrar:
#
# `Hola, Ana`
#
#
# Nota: terminar la función con `return` al final, aunque esta función no devuelve nada, solo muestra el mensaje

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 12. Función que calcula el doble
#
# Escribe una función llamada `doble`.
#
# La función debe recibir un número y devolver su doble.
#
# Ejemplo:
#
# ```python
# doble(4)
# ```
#
# debería devolver `8`.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 13. Función que calcula el triple
#
# Escribe una función llamada `triple`.
#
# La función debe recibir un número y devolver su triple.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 14. Función para sumar dos números
#
# Escribe una función llamada `sumar`.
#
# La función debe recibir dos números y devolver su suma.
#
# Ejemplo:
#
# ```python
# sumar(3, 5)
# ```
#
# debería devolver `8`.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 15. Función para calcular el área de un rectángulo
#
# Escribe una función llamada `area_rectangulo`.
#
# La función debe recibir dos parámetros:
#
# - `base`
# - `altura`
#
# Debe devolver el área del rectángulo.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 16. Función para calcular el precio con IVA
#
# Escribe una función llamada `precio_con_iva`.
#
# La función debe recibir un precio sin IVA y devolver el precio con un IVA del 21%.
#
# Ejemplo:
#
# ```python
# precio_con_iva(100)
# ```
#
# debería devolver `121`.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 17. Función para calcular el precio total
#
# Escribe una función llamada `precio_total`.
#
# La función debe recibir dos parámetros:
#
# - `precio`
# - `unidades`
#
# Debe devolver el coste total.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 18. Función para calcular una rebaja
#
# Escribe una función llamada `aplicar_descuento`.
#
# La función debe recibir:
#
# - `precio`
# - `descuento`
#
# El descuento se dará como número decimal.
#
# Ejemplo: un 20% de descuento se escribe como `0.20`.
#
# La función debe devolver el precio final.
#
# Pista:
#
# `precio_final = precio * (1 - descuento)`

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 19. Función para calcular ahorro mensual
#
# Escribe una función llamada `ahorro_mensual`.
#
# La función debe recibir:
#
# - `ingresos`
# - `gastos`
#
# Debe devolver cuánto dinero se ahorra:
#
# `ahorro = ingresos - gastos`

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 20. Función de salario semanal
#
# Escribe una función llamada `salario_semanal`.
#
# La función debe recibir:
#
# - `horas_trabajadas`
# - `pago_por_hora`
#
# Debe devolver el salario semanal.
#
# Después prueba la función con un ejemplo.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 21. Carga fichero csv
#
# Leer usando la biblioteca pandas el fichero que está en la url indicada por la variable `url`, dejando el resultado en una variable de nombre `df`

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/RafaelCaballero/tdm/refs/heads/master/datos/clientes.csv"

# Tu código aquí


# no tocar esto, es para ver el dataframe
df

# %% [markdown]
# ## Ejercicio 22. Escritura fichero excel
#
# Escribir el dataframe en la variable `df` en formato excel con nombre "clientes.xlsx"

# %% [markdown]
# # Ejercicio extra opcional
#
# Inventa una función propia relacionada con una situación cotidiana.
#
# Por ejemplo:
#
# - calcular el coste de una comida
# - calcular los kilómetros recorridos
# - calcular el precio de varias entradas de cine
# - calcular el dinero que queda después de una compra
# - alguna operación sencilla que utilices en el trabajo a menudo
#
# Escribe también un ejemplo de uso de la función

# %%
# Tu código aquí
