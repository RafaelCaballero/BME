# %% [markdown]
# <table>
# <tr>
# <td><img src="https://www.institutobme.es/dam/layout/bme-logo.svg" width="150"></td>
# <td><table><tr><td><h1>Ejercicios Numpy</h1></td></tr>
#            <tr><td><h3>Rafael Caballero Roldán</h3></td></tr></table></td>
#
# </tr>
# </table>

# %%
import numpy as np

# %% [markdown]
# ## Ejercicio 1.
#
# El array `ventas` contiene las ventas mensuales, en miles de euros, de una empresa durante un año.
#
# Obtén:
#
# 1. Las ventas de enero.
# 2. Las ventas de diciembre.
# 3. Las ventas del primer trimestre. ¿Cuál es el total? ¿y la media?
# 4. Las ventas del último trimestre.
# 5. Las ventas de marzo,febrero y abril, en ese orden

# %%
ventas = np.array([120, 135, 128, 150, 160, 170, 165, 158, 180, 190, 200, 210])

# Solución

# %% [markdown]
# ## Ejercicio 2. Filtrar valores mayores que la media
#
# El array `gastos` recoge los gastos mensuales de una familia, en euros.
#
# Calcula:
#
# 1. El gasto medio.
# 2. Los meses cuyo gasto está por encima de la media.
# 3. Cuántos meses están por encima de la media.

# %%
gastos = np.array([950, 1020, 870, 1100, 980, 1250, 900, 970, 1150, 1080, 990, 1300])

# Solución

# %% [markdown]
# ## Ejercicio 3.
#
# El array `paro` contiene la tasa de paro, en porcentaje, de varios años consecutivos.
#
# Obtén:
#
# 1. Las tasas de paro mayores o iguales que 10.
# 2. Las tasas de paro entre 8 y 12, ambos incluidos.
# 3. Un filtro que indique qué años tienen paro inferior a 9 o superior a 13.

# %%
paro = np.array([7.8, 8.5, 10.2, 12.1, 13.5, 11.8, 9.6, 8.9, 7.4])

# Solución

# %% [markdown]
# ## Ejercicio 4.
#
# El array `precios` contiene precios de varios productos.
#
# La empresa decide subir todos los precios un 6%.
#
# Calcula:
#
# 1. Los nuevos precios.
# 2. La diferencia absoluta entre el precio nuevo y el antiguo.
# 3. Los productos cuyo nuevo precio supera los 50 euros.

# %%
precios = np.array([25, 40, 55, 80, 12, 35, 60], dtype=float)

# Solución

# %% [markdown]
# ## Ejercicio 5.
#
# Los arrays `precio_unitario` y `cantidad_vendida` contienen información de varios productos.
#
# Calcula:
#
# 1. Los ingresos de cada producto.
# 2. El ingreso total.
# 3. El producto que más ingresos genera, devolviendo su posición. (Pista, investigar .max() y .argmax())
# 4. El mayor ingreso.

# %%
precio_unitario = np.array([10, 25, 8, 40, 15], dtype=float)
cantidad_vendida = np.array([100, 50, 200, 30, 120])

# Solución

# %% [markdown]
# ## Ejercicio 6. Estandarizar un array
#
# El array `salarios` contiene salarios mensuales, en euros.
#
# Calcula un nuevo array `salarios_z` donde cada salario esté estandarizado:
#
# $$z = \frac{x - \bar{x}}{s}$$
#
# donde $\bar{x}$ es la media (.mean()) y $s$ (.std()) la desviación típica.
#
# Después, obtén los salarios cuyo valor estandarizado sea mayor que 1.

# %%
salarios = np.array([1200, 1500, 1800, 2200, 2500, 3000, 4000], dtype=float)

# Solución

# %% [markdown]
# ## Ejercicio 7
#
# El array `salario_nominal` contiene salarios nominales de varios años.
#
# El array `ipc` contiene el índice de precios de esos años, con base 100.
#
# Calcula el salario real usando:
#
# $$salario\ real = \frac{salario\ nominal}{ipc} \cdot 100$$
#
# Después, calcula en qué años el salario real supera los 2100 euros.

# %%
salario_nominal = np.array([1800, 1900, 2000, 2150, 2300, 2500], dtype=float)
ipc = np.array([100, 103, 108, 115, 122, 130], dtype=float)

# Solución

# %% [markdown]
# ## Ejercicio 8.
# Los arrays `edad` e `ingresos` contienen información de varios clientes.
#
# Obtén:
#
# 1. Los ingresos de los clientes menores de 30 años.
# 2. Las edades de los clientes con ingresos superiores a 2500 euros.
# 3. Los ingresos de los clientes que tienen menos de 30 años y ganan más de 2000 euros.

# %%
edad = np.array([22, 35, 28, 40, 31, 25, 50, 29])
ingresos = np.array([1800, 2600, 2200, 3100, 2400, 2100, 4000, 1900])

# Solución

# %% [markdown]
# ## Ejercicio 9
#
# El array `pib` contiene el PIB de una economía durante varios años, en miles de millones desde 2018 hasta 2024, ambos inclusive
#
# Calcula la tasa de crecimiento anual, en porcentaje:
#
# $$crecimiento_t = \frac{pib_t - pib_{t-1}}{pib_{t-1}} \cdot 100$$
#
# No uses bucles.
#
# Después, obtén los años en los que el crecimiento fue negativo. Para simplificar, usa el array `anios_crecimiento`, que empieza en el segundo año.

# %%
pib = np.array([1050, 1080, 1115, 1090, 1120, 1170, 1195], dtype=float)
anios_crecimiento = np.array([2019, 2020, 2021, 2022, 2023, 2024])

# Escribe aquí tu código

# %% [markdown]
# ## Ejercicio 10. Rentabilidad de una cartera
#
# Los arrays `rent_A` y `rent_B` contienen rentabilidades mensuales, en porcentaje, de dos activos.
#
# Una cartera invierte:
#
# - 60% en el activo A.
# - 40% en el activo B.
#
# Calcula:
#
# 1. La rentabilidad mensual de la cartera.
# 2. La rentabilidad media mensual de la cartera.
# 3. Los meses en los que la cartera tuvo rentabilidad positiva.
# 4. La peor rentabilidad mensual de la cartera.

# %%
rent_A = np.array([1.2, -0.5, 2.0, 1.5, -1.0, 0.8], dtype=float)
rent_B = np.array([0.7, 0.2, 1.5, -0.3, -0.8, 1.0], dtype=float)

# Solución
