# %% [markdown]
# # Web Scraping con Python
#
# Este script muestra algunas posibilidades de la biblioteca *Selenium* que nos permite obtener, automáticamente, datos de páginas web dinámicas, es decir que necesitan pulsar botones, etc, etc.
#
# Selenium está pensado realmente para automatizar pruebas de entornos web, pero a nosotros nos servirá para nuestro propósito de hacer web scraping.
#
# En particular, lo que vamos a hacer es arrancar google Chrome y manejarlo automáticamente desde Python.
#
# Para ello necesitamos 3 cosas:
#
# 1.- Tener google Chrome
#
# 2.- Instalar la biblioteca selenium
#
# 3.- Tener un fichero controlador, un driver

# %% [markdown]
# Empezamos asegurarnos de que Selenium está instalado

# %%
modules = ["selenium","chromedriver_autoinstaller"]


import sys
import os.path
from subprocess import check_call
import importlib
import os

def instala(modules):
    print("Instalando módulos")
    for m in modules:
        # para el import quitamos [...] y ==...
        p = m.find("[")
        mi = m if p==-1 else m[:p]
        p = mi.find("==")
        mi = mi if p==-1 else mi[:p]
        torch_loader = importlib.util.find_spec(mi)
        if torch_loader is not None:
            print(m," encontrado")
        else:
            print(m," No encontrado, instalando...",end="")  
            try:        
                r = check_call([sys.executable, "-m", "pip", "install", "--user",  m])
                print("¡hecho!")
            except:
                print("¡Problema al instalar ",m,"! ¿seguro que el módulo existe?",sep="")

    print("¡Terminado!")

instala(modules)
# Out:
# Instalando módulos
# selenium  encontrado
# chromedriver_autoinstaller  encontrado
# ¡Terminado!

# %% [markdown]
# Ahora abrimos el navegador

# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
import chromedriver_autoinstaller

# setup chrome options
chrome_options = webdriver.ChromeOptions()
#chrome_options.add_argument('--headless') # ensure GUI is off
#chrome_options.add_argument('--no-sandbox')
#chrome_options.add_argument('--disable-dev-shm-usage')

# set path to chromedriver as per your configuration
chromedriver_autoinstaller.install()


# set up the webdriver
driver = webdriver.Chrome(options=chrome_options)

# %%
url = 'https://www1.sedecatastro.gob.es/CYCBienInmueble/OVCBusqueda.aspx'
driver.get(url)

# %% [markdown]
# Simulamos un click en la página de aceptar cookies

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time
#aceptar las cookies

try:
    cookies = driver.find_element(By.LINK_TEXT, "Aceptar cookies")
    cookies.click()
    print("Cookies aceptadas.")
except Exception as e:
    print("No se encontró el botón de aceptar cookies o ocurrió un error:", e)

# Hacer clic en la pestaña de coordenadas
try:
    coordenadas_tab = driver.find_element(By.LINK_TEXT, "COORDENADAS")
    coordenadas_tab.click()
    print("Se ha accedido a la pestaña de coordenadas.")
except Exception as e:
    print("No se encontró la pestaña de coordenadas o ocurrió un error:")
#coord.click()
# Out:
# Cookies aceptadas.
# Se ha accedido a la pestaña de coordenadas.

# %% [markdown]
# datos de Coordenadas

# %%
#lat = driver.find_element_by_id("ctl00_Contenido_txtLatitud")
#lon = driver.find_element_by_id("ctl00_Contenido_txtLongitud")
lat = driver.find_element(By.ID, "ctl00_Contenido_txtLatitud")

lon = driver.find_element(By.ID, "ctl00_Contenido_txtLongitud")
latitud  = "28.2723368"
longitud = "-16.64268"
lat.send_keys(latitud)
lon.send_keys(longitud)

# %% [markdown]
# Pulsar Botón para acceder a los datos concretos

# %%
datos = driver.find_element(By.ID, "ctl00_Contenido_btnDatos")
datos.click()

# %%
id = "ctl00_Contenido_tblInmueble"
#div = driver.find_element("id")
labels = driver.find_elements(By.XPATH, "//label")
for i,l in enumerate(labels):
    print(i,l.text)
# Out:
# 0 38026A035000010000EI
# 1
# 2
# 3 Polígono 35 Parcela 1 PARQUE NACINAL DEL TEIDE
# MONTE. LA OROTAVA (S.C. TENERIFE)
# 4 Rústico
# 5 Agrario
# 6
# 7 3.704 m2
# 8 1965
# 9 Polígono 35 Parcela 1 PARQUE NACINAL DEL TEIDE
# MONTE. LA OROTAVA (S.C. TENERIFE)
# 10 73.628.811 m2
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18

# %% [markdown]
# Referencia catastral

# %%
id = "ctl00_Contenido_tblInmueble"
pos = [0,3,4,5,7,8]
div = driver.find_element(By.ID,id)
labels = div.find_elements(By.XPATH,"//label")
for i,label in enumerate(labels):
    if i in pos:
        print(label.text)
# Out:
# 38026A035000010000EI
# Polígono 35 Parcela 1 PARQUE NACINAL DEL TEIDE
# MONTE. LA OROTAVA (S.C. TENERIFE)
# Rústico
# Agrario
# 3.704 m2
# 1965

# %% [markdown]
# Todo Junto

# %%
import pandas as pd
file = "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/catastro.csv"
df = pd.read_csv(file)
df
# Out:
#                     _id  followers                        location  \
# 0             148076807        515            19.447297,-70.678351
# 1             557076972       1022                             BCN
# 2    800430827947442176         20                Valencia, España
# 3            1187834312        653                   Madrid, Spain
# 4            3153928585         99               Málaga, Andalucía
# 5              18901057       1562                UK/Brasil/España
# 6             117884436       1502                       Barcelona
# 7    761237429072388096         35     Madrid, Comunidad de Madrid
# 8             184959473        733            LA MANCHA y SEVILLA
# 9            2838312285         27                          España
# 10            984999942       1239                           Elche
# 11            287826955       2244                       Salamanca
# 12            292027758       2442                 madrid (españa)
# 13            459477808        697               Estadio de Riazor
# 14            875433438        491        De Salamanca, en Madrid
# 15             89165765      27536                          Madrid
# 16           2378742043        106                        valencia
# 17   701379658600882176        168                   Elche, España
# 18             42004114       2340           Canary Islands, Spain
# 19            299264539        147  Santa Cruz de Tenerife, España
# 20             96663968       1394               Budapest, Hungría
# 21   913311027407802368         44                  Madrid, España
# 22            180333341        413                Valencia, España
# 23           1974659378       2198                       Barcelona
# 24   745651197286162432        203                 Carmona, España
# 25             92629354        981                Zaragoza, España
# 26           4069778056        702                   Madrid, Spain
# 27            996055734        475  Móstoles-Madrid/Orihuela Costa
# 28            278039896        241                       Barcelona
# 29            118352921       2961                   Madrid ,Spain
# 30            270010775         39              Felgosas-A Coruña
# 31            184537316        408                        PARAGUAY
# 32           1580184631        102                          Elche.
# 33   719905537396228096        706                    Mijas, Spain
# 34           1495328876        763     Madrid, Comunidad de Madrid
# 35            246837853       2480                          Madrid
# 36            142451580         52                          Madrid
# 37            709714971        872                  Málaga, España
# 38             15703541       5084                Washington, D.C.
# 39           1553476147        214                  Madrid - Spain
# 40   849681349162283008        217  Principado de Asturias, España
# 41            757471410        324               Glasgow, Scotland
# 42           1122025458        846                A Coruña, España
# 43            233345061       2437                        Albacete
# 44           1723462104        103               Torrent, Valencia
# 45             84143687       1814                Madrid - Cáceres
# 46            106841104         90             Cuidotumascota.com
# 47            943230391         64                         Arteixo
# 48  1337479172441169920       1328                 Sevilla, España
# 49            446433608        924                   Villalba Sity
# 50            490529286        431                         JLAM  ∞
# 51           3352643962        256                Valencia, España
# 52            799512942       1149      Las Palmas, Islas Canarias
#
#         screen_name  verified       long        lat
# 0       eugenio_sky     False  -3.685060  40.427170
# 1       annetapedro     False   2.176402  41.405603
# 2     Trastarteando     False  -0.293131  39.567629
# 3        manukareol     False  -3.705050  40.438520
# 4   PedroMendez_mlg     False  -4.407480  36.720087
# 5        GuitarCafe     False   0.060693  40.052917
# 6       Ldiazalonso     False  -3.707360  40.421380
# 7            fjdemi     False  -3.584300  40.360320
# 8    DonaireAlberto     False  -3.930790  38.986850
# 9      begonabotana     False  -8.410720  43.355270
# 10  DeportesSinAdje     False  -0.495255  38.354110
# 11       AlexLorrys     False  -5.665297  40.995588
# 12     juanemilioma     False  -3.703560  40.413900
# 13       carrinho_7     False  -8.417591  43.368882
# 14      veracoteloc     False  -3.682013  40.413704
# 15        martuniki      True  -3.555100  40.423200
# 16   alvarotriatlon     False  -0.332990  39.569176
# 17    juancaitan999     False  -0.744040  38.227070
# 18  sheilacrosby403     False -17.775510  28.641670
# 19  cocinadedolores     False -16.506800  28.413808
# 20       GGabrielaH     False  -3.709150  40.419110
# 21         Xoroto82     False  -3.555100  40.423200
# 22        _albertt_     False  -3.696575  40.416390
# 23          sr_boca     False   2.153530  41.394350
# 24    Santa_MartaSL     False  -5.646853  37.481902
# 25         javinumy     False  -0.903900  41.634790
# 26     eliaonmymind     False   4.242396  39.820458
# 27       LidiaMP_12     False  -3.575250  40.207000
# 28  capitanspavento     False   2.167317  41.375952
# 29    fvazquezmedem     False  -3.684590  40.427830
# 30    ReinaldoReini     False  -8.285718  43.315855
# 31        miguelx94     False  -8.176534  43.496028
# 32     josevcanales     False  -0.643128  38.219706
# 33      AlanDreezer     False  -4.673660  36.555811
# 34   Pablocarroglez     False  -3.746949  40.322687
# 35    Kutxi_Pacheco     False  -3.700420  40.440970
# 36  murcianicaguapa     False  -8.782765  42.264213
# 37      MarPadilla_     False  -4.461353  36.666172
# 38        wbdnewton     False  -3.707360  40.421380
# 39   MuchoFunkSpain     False  -3.457420  40.446570
# 40    sparacingfoto     False  -3.686452  43.388387
# 41   20_Tina_Torres     False  -3.711527  40.422560
# 42         acasar51     False  -8.264650  43.322800
# 43   A_MtnezIniesta     False  -3.692180  40.419010
# 44         adolvale     False  -0.466667  39.433300
# 45        Alpaniagu     False  -3.703260  40.464447
# 46           OLKI69     False  -3.584300  40.360320
# 47     chelodxastre     False  -8.401650  43.369760
# 48   CajonSevillano     False  -5.990828  37.389712
# 49     SandraAyuso_     False  -3.985473  40.644887
# 50    likeblueskies     False  -3.656678  40.520858
# 51   alexvelasco943     False   0.050000  38.650000
# 52      BombonKarol     False -17.980833  27.641944

# %%
from time import sleep
df = pd.read_csv(file)
coldf = len(df.columns)
url = 'https://www1.sedecatastro.gob.es/CYCBienInmueble/OVCBusqueda.aspx'
# mejor con una lista de lsitas, pero así se entiende mejor
pos = [0,3,4,5,7,8]
nombres = ["ref","loc","clase","uso","superficie","año"]
df[nombres] = None
filenum = 0
for row in df.iterrows():
    # los datos están en row[1], row[0] es el índice
    fila = row[1]
    driver.get(url)
    coord   = driver.find_element(By.LINK_TEXT,"COORDENADAS")
    coord.click()
    sleep(0.5)
    # coordenadas
    lat = driver.find_element(By.ID,"ctl00_Contenido_txtLatitud")
    lon = driver.find_element(By.ID,"ctl00_Contenido_txtLongitud")
    latitud  = str(fila["lat"])
    longitud = str(fila["long"])
    lat.send_keys(latitud)
    lon.send_keys(longitud)
    sleep(0.25)
    # pulsar el botón, esto puede tardar
    datos = driver.find_element(By.ID,"ctl00_Contenido_btnDatos")
    datos.click()

    sleep(1.5)
    id = "ctl00_Contenido_tblInmueble"
    pos = [0,3,4,5,7,8]
    div = driver.find_elements(By.ID,id)
    if len(div)==1:
        div = div[0]
        labels = div.find_elements(By.XPATH,"//label")
        for i,label in enumerate(labels):
            if i in pos:
                df.iloc[filenum,coldf+pos.index(i)] = label.text
    filenum+=1

# %%
df
# Out:
#                     _id  followers                        location  \
# 0             148076807        515            19.447297,-70.678351
# 1             557076972       1022                             BCN
# 2    800430827947442176         20                Valencia, España
# 3            1187834312        653                   Madrid, Spain
# 4            3153928585         99               Málaga, Andalucía
# 5              18901057       1562                UK/Brasil/España
# 6             117884436       1502                       Barcelona
# 7    761237429072388096         35     Madrid, Comunidad de Madrid
# 8             184959473        733            LA MANCHA y SEVILLA
# 9            2838312285         27                          España
# 10            984999942       1239                           Elche
# 11            287826955       2244                       Salamanca
# 12            292027758       2442                 madrid (españa)
# 13            459477808        697               Estadio de Riazor
# 14            875433438        491        De Salamanca, en Madrid
# 15             89165765      27536                          Madrid
# 16           2378742043        106                        valencia
# 17   701379658600882176        168                   Elche, España
# 18             42004114       2340           Canary Islands, Spain
# 19            299264539        147  Santa Cruz de Tenerife, España
# 20             96663968       1394               Budapest, Hungría
# 21   913311027407802368         44                  Madrid, España
# 22            180333341        413                Valencia, España
# 23           1974659378       2198                       Barcelona
# 24   745651197286162432        203                 Carmona, España
# 25             92629354        981                Zaragoza, España
# 26           4069778056        702                   Madrid, Spain
# 27            996055734        475  Móstoles-Madrid/Orihuela Costa
# 28            278039896        241                       Barcelona
# 29            118352921       2961                   Madrid ,Spain
# 30            270010775         39              Felgosas-A Coruña
# 31            184537316        408                        PARAGUAY
# 32           1580184631        102                          Elche.
# 33   719905537396228096        706                    Mijas, Spain
# 34           1495328876        763     Madrid, Comunidad de Madrid
# 35            246837853       2480                          Madrid
# 36            142451580         52                          Madrid
# 37            709714971        872                  Málaga, España
# 38             15703541       5084                Washington, D.C.
# 39           1553476147        214                  Madrid - Spain
# 40   849681349162283008        217  Principado de Asturias, España
# 41            757471410        324               Glasgow, Scotland
# 42           1122025458        846                A Coruña, España
# 43            233345061       2437                        Albacete
# 44           1723462104        103               Torrent, Valencia
# 45             84143687       1814                Madrid - Cáceres
# 46            106841104         90             Cuidotumascota.com
# 47            943230391         64                         Arteixo
# 48  1337479172441169920       1328                 Sevilla, España
# 49            446433608        924                   Villalba Sity
# 50            490529286        431                         JLAM  ∞
# 51           3352643962        256                Valencia, España
# 52            799512942       1149      Las Palmas, Islas Canarias
#
#         screen_name  verified       long        lat                       ref  \
# 0       eugenio_sky     False  -3.685060  40.427170  2055317VK4725E0001BL
# 1       annetapedro     False   2.176402  41.405603  1242504DF3814C0001BL
# 2     Trastarteando     False  -0.293131  39.567629  2634601YJ3823S0001XX
# 3        manukareol     False  -3.705050  40.438520  0167607VK4706G0001EM
# 4   PedroMendez_mlg     False  -4.407480  36.720087  4449101UF7644N0001SA
# 5        GuitarCafe     False   0.060693  40.052917  9480003BE4398S0001WA
# 6       Ldiazalonso     False  -3.707360  40.421380  0149302VK4704G0001QS
# 7            fjdemi     False  -3.584300  40.360320  0480404VK5608A0001WP
# 8    DonaireAlberto     False  -3.930790  38.986850  9559001VJ1195N0001IQ
# 9      begonabotana     False  -8.410720  43.355270  7807017NJ4070N0001TY
# 10  DeportesSinAdje     False  -0.495255  38.354110  9082301YH1498C0001GM
# 11       AlexLorrys     False  -5.665297  40.995588  6017501TL7461N0001JS
# 12     juanemilioma     False  -3.703560  40.413900  0440301VK4704A0001GR
# 13       carrinho_7     False  -8.417591  43.368882  7321001NJ4072S0001FW
# 14      veracoteloc     False  -3.682013  40.413704  2043558VK4724C0001FU
# 15        martuniki      True  -3.555100  40.423200  3050001VK5735S0001JO
# 16   alvarotriatlon     False  -0.332990  39.569176  9135424YJ2893N0001RU
# 17    juancaitan999     False  -0.744040  38.227070  7636113XH9373F0018AE
# 18  sheilacrosby403     False -17.775510  28.641670  38009A009090490000TU
# 19  cocinadedolores     False -16.506800  28.413808  2541201CS5424S0001AO
# 20       GGabrielaH     False  -3.709150  40.419110  9947618VK3794F0001SR
# 21         Xoroto82     False  -3.555100  40.423200  3050001VK5735S0001JO
# 22        _albertt_     False  -3.696575  40.416390  0944701VK4704D0001AI
# 23          sr_boca     False   2.153530  41.394350  9230909DF2893A0001WR
# 24    Santa_MartaSL     False  -5.646853  37.481902  6019113TG6561N0001MX
# 25         javinumy     False  -0.903900  41.634790  4615601XM7141F0001YU
# 26     eliaonmymind     False   4.242396  39.820458  6288015FE0068N0001IE
# 27       LidiaMP_12     False  -3.575250  40.207000  1111517VK5511S0001IG
# 28  capitanspavento     False   2.167317  41.375952  0410615DF3801A0001ZG
# 29    fvazquezmedem     False  -3.684590  40.427830  2057908VK4725E0001ML
# 30    ReinaldoReini     False  -8.285718  43.315855  8063102NH5986S0001UO
# 31        miguelx94     False  -8.176534  43.496028  6665031NJ6166N0001RK
# 32     josevcanales     False  -0.643128  38.219706  6430118YH0363A0001GY
# 33      AlanDreezer     False  -4.673660  36.555811  0371107UF5407S0001KB
# 34   Pablocarroglez     False  -3.746949  40.322687  6642702VK3664S0001BZ
# 35    Kutxi_Pacheco     False  -3.700420  40.440970  0771230VK4707B0001QK
# 36  murcianicaguapa     False  -8.782765  42.264213  8093228NG1789S0001BP
# 37      MarPadilla_     False  -4.461353  36.666172  9690118UF6599S0001KG
# 38        wbdnewton     False  -3.707360  40.421380  0149302VK4704G0001QS
# 39   MuchoFunkSpain     False  -3.457420  40.446570                      None
# 40    sparacingfoto     False  -3.686452  43.388387  4444003VP4044S0001QH
# 41   20_Tina_Torres     False  -3.711527  40.422560  9751815VK3795B0001FI
# 42         acasar51     False  -8.264650  43.322800  15008A049003210000XS
# 43   A_MtnezIniesta     False  -3.692180  40.419010  1446401VK4714E0001HZ
# 44         adolvale     False  -0.466667  39.433300  8181610YJ1688S0001OT
# 45        Alpaniagu     False  -3.703260  40.464447                      None
# 46           OLKI69     False  -3.584300  40.360320  0480404VK5608A0001WP
# 47     chelodxastre     False  -8.401650  43.369760  8522414NJ4082S0001UY
# 48   CajonSevillano     False  -5.990828  37.389712  5324411TG3452C0001DP
# 49     SandraAyuso_     False  -3.985473  40.644887  6800028VL1060S0001YY
# 50    likeblueskies     False  -3.656678  40.520858  4965842VK4846S0001SM
# 51   alexvelasco943     False   0.050000  38.650000  5725002BC6852N0001IL
# 52      BombonKarol     False -17.980833  27.641944  6009307BR0660N0001GO
#
#                                                   loc    clase  \
# 0                CL LAGASCA 60\n28001 MADRID (MADRID)   Urbano
# 1        CL MALLORCA 425\n08013 BARCELONA (BARCELONA)   Urbano
# 2   AV MAR 25 Bl:A\n46137 LA POBLA DE FARNALS (VAL...   Urbano
# 3   CL BRAVO MURILLO 47 TEATROS DEL CANAL\n28015 M...   Urbano
# 4                 PS REDING 22\n29016 MALAGA (MÁLAGA)   Urbano
# 5   AV CASTELLON 19\n12560 BENICASIM / BENICASSIM ...   Urbano
# 6               CL GRAN VIA 54\n28013 MADRID (MADRID)   Urbano
# 7    AV CERRO MILANO 537 U.E.5\n28031 MADRID (MADRID)   Urbano
# 8         CL PRADO 5\n13002 CIUDAD REAL (CIUDAD REAL)   Urbano
# 9        CL SAN VICENTE 16\n15007 A CORUÑA (A CORUÑA)   Urbano
# 10  CL FOGUERER RAMON GUILABERT 8\n03005 ALICANTE/...   Urbano
# 11  CR ZAMORA 1 Pl:00\n37189 VILLARES DE LA REINA ...   Urbano
# 12                CL ATOCHA 18\n28012 MADRID (MADRID)   Urbano
# 13       AV BUENOS AIRES 1\n15004 A CORUÑA (A CORUÑA)   Urbano
# 14      PS REPUBLICA DE CUBA 4\n28006 MADRID (MADRID)   Urbano
# 15  CL MIGUEL HERNANDEZ 1(A) Suelo G\n28820 COSLAD...   Urbano
# 16  CL MESTRE ROQUE GORRIZ 10\n46130 MASSAMAGRELL ...   Urbano
# 17           AV ALGODA 27\n03296 ELCHE/ELX (ALICANTE)   Urbano
# 18  Polígono 9 Parcela 9049\nCR GRAL SUR. BREÑA BA...  Rústico
# 19   CR PINITO 11\n38390 SANTA URSULA (S.C. TENERIFE)   Urbano
# 20             CL CAMPOMANES 8\n28013 MADRID (MADRID)   Urbano
# 21  CL MIGUEL HERNANDEZ 1(A) Suelo G\n28820 COSLAD...   Urbano
# 22                 PZ CORTES 1\n28014 MADRID (MADRID)   Urbano
# 23  CL ENRIC GRANADOS 147\n08008 BARCELONA (BARCEL...   Urbano
# 24             CL CALEROS 10\n41410 CARMONA (SEVILLA)   Urbano
# 25  CL JUAN II DE ARAGON 5\n50009 ZARAGOZA (ZARAGOZA)   Urbano
# 26  CM ANGUILA TORTA, DE S' 45 Suelo\n07711 SANT L...   Urbano
# 27  CL CAMPOAMOR 25\n28330 SAN MARTIN DE LA VEGA (...   Urbano
# 28           CL FLORS 22\n08001 BARCELONA (BARCELONA)   Urbano
# 29            CL AYALA 27 0000\n28001 MADRID (MADRID)   Urbano
# 30        LG ESPIRITO SANTO 26\n15168 SADA (A CORUÑA)   Urbano
# 31                UR COUTO 63\n15570 NARON (A CORUÑA)   Urbano
# 32           CL MUTXOL 28\n03292 ELCHE/ELX (ALICANTE)   Urbano
# 33      CL ROMA DE MIJAS GOLF 2\n29650 MIJAS (MÁLAGA)   Urbano
# 34        CL JULIO PALACIOS 5\n28914 LEGANES (MADRID)   Urbano
# 35  PZ DESCUBRIDOR DIEGO ORDAS 7 Suelo\n28003 MADR...   Urbano
# 36               RU SOL 29\n36940 CANGAS (PONTEVEDRA)   Urbano
# 37  CL ACACIAS DE GUADALMAR 20(A)\n29004 MALAGA (M...   Urbano
# 38              CL GRAN VIA 54\n28013 MADRID (MADRID)   Urbano
# 39                                               None     None
# 40  CR HOZNAYO-BILBAO 75(G)\n39716 ENTRAMBASAGUAS ...   Urbano
# 41                 PZ ESPAÑA 3\n28008 MADRID (MADRID)   Urbano
# 42  LG RUA LAMA Polígono 49 Parcela 321\nAGRUMIAS....  Rústico
# 43             PZ CIBELES 1(A)\n28014 MADRID (MADRID)   Urbano
# 44         CL SANTA RITA 10\n46900 TORRENT (VALENCIA)   Urbano
# 45                                               None     None
# 46   AV CERRO MILANO 537 U.E.5\n28031 MADRID (MADRID)   Urbano
# 47              CL OLMOS 3\n15003 A CORUÑA (A CORUÑA)   Urbano
# 48         CL SAN ISIDORO 15\n41004 SEVILLA (SEVILLA)   Urbano
# 49  UR ALHAMBRA 1(I)\n28400 COLLADO VILLALBA (MADRID)   Urbano
# 50  CL DIEGO SALMERON Ndup-A\n28108 ALCOBENDAS (MA...   Urbano
# 51          PD GARGASINDI 2(K)\n03710 CALP (ALICANTE)   Urbano
# 52  CL JUAN GUTIERREZ MONTEVER 20 LA RESTINGA\n389...   Urbano
#
#                 uso superficie   año
# 0       Residencial   2.986 m2  1900
# 1         Comercial   4.077 m2  1993
# 2         Deportivo   5.754 m2  1978
# 3      Espectáculos  38.382 m2  2008
# 4   Ocio,Hostelería  24.510 m2  1936
# 5          Cultural     798 m2  1940
# 6          Oficinas   9.315 m2  1929
# 7       Residencial     247 m2  2019
# 8         Religioso   2.968 m2  1500
# 9       Residencial     494 m2  1958
# 10        Deportivo   8.524 m2  1993
# 11        Deportivo   7.480 m2  1970
# 12     Espectáculos   6.497 m2  2011
# 13        Deportivo  53.774 m2  2005
# 14  Ocio,Hostelería   1.295 m2  1975
# 15  Suelo sin edif.  42.705 m2
# 16      Residencial     708 m2  1955
# 17      Residencial     288 m2  1950
# 18          Agrario   6.039 m2
# 19        Comercial   1.152 m2  1960
# 20      Residencial   3.406 m2  1940
# 21  Suelo sin edif.  42.705 m2
# 22   Edif. Singular  38.888 m2  1850
# 23      Residencial   1.115 m2  1915
# 24       Industrial   2.525 m2  2002
# 25        Comercial   2.889 m2  1971
# 26  Suelo sin edif.     952 m2
# 27      Residencial     187 m2  1986
# 28     Espectáculos     849 m2  1941
# 29      Residencial   4.275 m2  1931
# 30        Religioso   3.607 m2  1940
# 31      Residencial     251 m2  1997
# 32      Residencial     256 m2  1995
# 33  Suelo sin edif.   1.575 m2
# 34       Industrial   9.664 m2  1990
# 35  Suelo sin edif.   3.226 m2
# 36      Residencial     164 m2  1965
# 37      Residencial     488 m2  1996
# 38         Oficinas   9.315 m2  1929
# 39             None       None  None
# 40       Industrial     176 m2  1900
# 41  Ocio,Hostelería  24.288 m2  2017
# 42          Agrario      86 m2  2007
# 43         Oficinas  52.949 m2  1999
# 44      Residencial     105 m2  1930
# 45             None       None  None
# 46      Residencial     247 m2  2019
# 47       Industrial     200 m2  1900
# 48        Religioso   1.431 m2  1900
# 49        Deportivo     786 m2  1980
# 50       Industrial   5.585 m2  1980
# 51  Suelo sin edif.   3.797 m2
# 52      Residencial     102 m2  1995

# %% [markdown]
# ### Más pruebas

# %% [markdown]
# Texto de la página

# %%
html = driver.find_element(By.XPATH,"/html")
print(html.text)
# Out:
# Formulario master
# Castellano
# ICONO CORREO ELECTRÓNICO
# CONTÁCTENOS
# Icono página de inicio
# Consulta y certificación de Bien Inmueble
# Volver
# CARTOGRAFÍA
# CONSULTA DESCRIPTIVA Y GRÁFICA
# EXPEDIENTES ABIERTOS
# IMPRIMIR DATOS
# VISOR 3D
# DATOS DESCRIPTIVOS DEL INMUEBLE
# Referencia catastral
# 6009307BR0660N0001GO
# Localización
# CL JUAN GUTIERREZ MONTEVER 20 LA RESTINGA
# 38914 EL PINAR DE EL HIERRO (RESTINGA LA) (S.C. TENERIFE)
# Clase
# Urbano
# Uso principal
# Residencial
# Superficie construida
# 102 m2
# Año construcción
# 1995
# PARCELA CATASTRAL
#
# Parcela construida sin división horizontal
# Localización
# CL JUAN GUTIERREZ MONTEVER 20 LA RESTINGA
# EL PINAR DE EL HIERRO (RESTINGA LA) (S.C. TENERIFE)
# Superficie gráfica
# 48 m2
# CONSTRUCCIÓN
# Uso principal Escalera Planta Puerta Superficie m2 Tipo Reforma Fecha Reforma
# VIVIENDA 00 01 48
# VIVIENDA 01 48
# ALMACEN 02 01 6
# ¿Cómo se pueden obtener datos protegidos (titularidad y valor catastral) de los inmuebles y certificados telemáticos de los mismos?
#
#
#
#
#
#
#
#
# Normativa reguladora
# Política de privacidad
# Accesibilidad
# Mapa web

# %% [markdown]
# Caminos absolutos

# %%
head = driver.find_element(By.XPATH,"/html/head")
body = driver.find_element(By.XPATH,"/html/body")
html2 = body.find_element(By.XPATH,"/html")

# %%
print(body.text)
# Out:
# Formulario master
# Castellano
# ICONO CORREO ELECTRÓNICO
# CONTÁCTENOS
# Icono página de inicio
# Consulta y certificación de Bien Inmueble
# Volver
# CARTOGRAFÍA
# CONSULTA DESCRIPTIVA Y GRÁFICA
# EXPEDIENTES ABIERTOS
# IMPRIMIR DATOS
# VISOR 3D
# DATOS DESCRIPTIVOS DEL INMUEBLE
# Referencia catastral
# 6009307BR0660N0001GO
# Localización
# CL JUAN GUTIERREZ MONTEVER 20 LA RESTINGA
# 38914 EL PINAR DE EL HIERRO (RESTINGA LA) (S.C. TENERIFE)
# Clase
# Urbano
# Uso principal
# Residencial
# Superficie construida
# 102 m2
# Año construcción
# 1995
# PARCELA CATASTRAL
#
# Parcela construida sin división horizontal
# Localización
# CL JUAN GUTIERREZ MONTEVER 20 LA RESTINGA
# EL PINAR DE EL HIERRO (RESTINGA LA) (S.C. TENERIFE)
# Superficie gráfica
# 48 m2
# CONSTRUCCIÓN
# Uso principal Escalera Planta Puerta Superficie m2 Tipo Reforma Fecha Reforma
# VIVIENDA 00 01 48
# VIVIENDA 01 48
# ALMACEN 02 01 6
# ¿Cómo se pueden obtener datos protegidos (titularidad y valor catastral) de los inmuebles y certificados telemáticos de los mismos?
#
#
#
#
#
#
#
#
# Normativa reguladora
# Política de privacidad
# Accesibilidad
# Mapa web

# %% [markdown]
# Hijos de un elemento

# %%
hijos = driver.find_elements(By.XPATH,"/html/body/*")
for element in hijos:
  print(element.tag_name)
# Out:
# div
# div
# form
# div
# script
# a
# script
# link
# script
# script
# script

# %% [markdown]
# Camino relativo

# %%
divs = driver.find_elements(By.XPATH,"/html/body/*/div")
print(len(divs))

# %%
divs = body.find_elements(By.XPATH,"./*/div")
print(len(divs))

# %% [markdown]
# Saltar pasos intermedios

# %%
divs = driver.find_elements(By.XPATH,"/html/body//div")
print(len(divs))

# %%
labels = driver.find_elements(By.XPATH,"//label")
print(len(labels))

# %% [markdown]
# Insertar texto

# %%
lat = driver.find_element(By.ID,"ctl00_Contenido_txtLatitud")
lon = driver.find_element(By.ID,"ctl00_Contenido_txtLongitud")
latitud  = "28.2723368"
longitud = "-16.64268"
lat.send_keys(latitud)
lon.send_keys(longitud)

# %%
datos = driver.find_element(By.ID,"ctl00_Contenido_btnDatos")
datos.click()

# %%
id = "ctl00_Contenido_tblInmueble"
div = driver.find_element(By.ID,id)
label = div.find_element(By.XPATH,"//label")
print(label.text)

# %% [markdown]
# Otra forma, por texto

# %%
xpath = "//*[./span/text()='Referencia catastral']//label"
etiqs = driver.find_element(By.XPATH,xpath)
print(etiqs.text)

# %% [markdown]
# Algunos ejemplos más....

# %%
clase = driver.find_elements(By.XPATH,"(//label)[position()=3]")
print(clase[0].text)

etiqs = driver.find_elements(By.XPATH,"//label")
print(etiqs[2].text)

ulti = driver.find_elements(By.XPATH,"(//label)[last()]")
print(ulti[0].text)

# %% [markdown]
# Un pequeño ejemplo adicional, información metereológica en Madrid

# %%
url2 = 'http://www.aemet.es/es/eltiempo/prediccion/municipios/madrid-id28079'
driver.get(url2)

# %%
th = driver.find_elements(By.XPATH,"/html/body//*/th")
print(len(th))
th = driver.find_elements(By.XPATH,"/html/body//*/th[@class='borde_izq_dcha_estado_cielo no_wrap']")
print(len(th))
for e in th:
    print(e.text)

# %%
driver.close()

# %% [markdown]
# Por Rafael Caballero. Del libro "Big data con Python". Gracias a José Ramón Guerra por las actualizaciones
