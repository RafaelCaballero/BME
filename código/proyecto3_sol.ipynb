# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelCaballero/BME/blob/main/c%C3%B3digo/proyecto3_sol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Curso Python – Proyecto 3
# El siguiente fichero contiene datos de diferentes vinos
# "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/wines_SPA.csv"
#
# 1) Cargar el fichero y dejarlo en un dataframe df

# %%
import pandas as pd
# Solución
url = "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/wines_SPA.csv"
df = pd.read_csv(url)

df
# Out:
#                     winery             wine  year  rating  num_reviews  \
# 0            Teso La Monja            Tinto  2013     4.9           58
# 1                   Artadi    Vina El Pison  2018     4.9           31
# 2             Vega Sicilia            Unico  2009     4.8         1793
# 3             Vega Sicilia            Unico  1999     4.8         1705
# 4             Vega Sicilia            Unico  1996     4.8         1309
# ...                    ...              ...   ...     ...          ...
# 7495               Contino          Reserva  2016     4.2          392
# 7496  Conreria d'Scala Dei    Les Brugueres  2018     4.2          390
# 7497           Mustiguillo  Finca Terrerazo  2017     4.2          390
# 7498           Matarromera     Gran Reserva  2011     4.2          389
# 7499              Sei Solo         Preludio  2016     4.2          388
#
#      country            region   price                  type  body  acidity
# 0     Espana              Toro  995.00              Toro Red   5.0      3.0
# 1     Espana    Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2     Espana  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3     Espana  Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4     Espana  Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0
# ...      ...               ...     ...                   ...   ...      ...
# 7495  Espana             Rioja   19.98             Rioja Red   4.0      3.0
# 7496  Espana          Priorato   16.76           Priorat Red   4.0      3.0
# 7497  Espana      El Terrerazo   24.45                   Red   4.0      3.0
# 7498  Espana  Ribera del Duero   64.50  Ribera Del Duero Red   5.0      3.0
# 7499  Espana  Ribera del Duero   31.63  Ribera Del Duero Red   5.0      3.0
#
# [7500 rows x 11 columns]

# %% [markdown]
# 2) ¿Cuántas filas y columnas tiene?

# %%
# Solución
f,c = df.shape
print(f"Tiene {f} filas y {c} columnas")
# Out:
# Tiene 7500 filas y 11 columnas

# %% [markdown]
# 3) Escribir instrucciones para ver datos básicos del dataframe. En particular nos interesa determinar ¿hay nulos en alguna columna? ¿cuál es el precio del vino más caro? ¿y del más barato?

# %%
# Solución
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   winery       7500 non-null   object
#  1   wine         7500 non-null   object
#  2   year         7498 non-null   object
#  3   rating       7500 non-null   float64
#  4   num_reviews  7500 non-null   int64
#  5   country      7500 non-null   object
#  6   region       7500 non-null   object
#  7   price        7500 non-null   float64
#  8   type         6955 non-null   object
#  9   body         6331 non-null   float64
#  10  acidity      6331 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 644.7+ KB

# %% [markdown]
# Observamos que las columnas `type`, `body`y `acidity` tiene nulos

# %%
df.describe()
# Out:
#             rating   num_reviews        price         body      acidity
# count  7500.000000   7500.000000  7500.000000  6331.000000  6331.000000
# mean      4.254933    451.109067    60.095822     4.158427     2.946612
# std       0.118029    723.001856   150.356676     0.583352     0.248202
# min       4.200000     25.000000     4.990000     2.000000     1.000000
# 25%       4.200000    389.000000    18.900000     4.000000     3.000000
# 50%       4.200000    404.000000    28.530000     4.000000     3.000000
# 75%       4.200000    415.000000    51.350000     5.000000     3.000000
# max       4.900000  32624.000000  3119.080000     5.000000     3.000000

# %% [markdown]
# 4) Mostrar solo la columna type

# %%
# Solución
df[ ["type"] ]
# Out:
#                       type
# 0                 Toro Red
# 1              Tempranillo
# 2     Ribera Del Duero Red
# 3     Ribera Del Duero Red
# 4     Ribera Del Duero Red
# ...                    ...
# 7495             Rioja Red
# 7496           Priorat Red
# 7497                   Red
# 7498  Ribera Del Duero Red
# 7499  Ribera Del Duero Red
#
# [7500 rows x 1 columns]

# %% [markdown]
# 5) Mostrar solo las columnas type y body

# %%
# Solución
df2 = df[ ["type", "body"] ]
df2
# Out:
#                       type  body
# 0                 Toro Red   5.0
# 1              Tempranillo   4.0
# 2     Ribera Del Duero Red   5.0
# 3     Ribera Del Duero Red   5.0
# 4     Ribera Del Duero Red   5.0
# ...                    ...   ...
# 7495             Rioja Red   4.0
# 7496           Priorat Red   4.0
# 7497                   Red   4.0
# 7498  Ribera Del Duero Red   5.0
# 7499  Ribera Del Duero Red   5.0
#
# [7500 rows x 2 columns]

# %% [markdown]
# 6) Mostrar solo el vino que ocupa la 5ª posición en el dataframe

# %%
# Solución
df.iloc[[4]]
# Out:
#          winery   wine  year  rating  num_reviews country            region  \
# 4  Vega Sicilia  Unico  1996     4.8         1309  Espana  Ribera del Duero
#
#     price                  type  body  acidity
# 4  778.06  Ribera Del Duero Red   5.0      3.0

# %% [markdown]
# 7) Obtener los valores diferentes de la columna `region` y la frecuencia de cada uno de ellos

# %%
# solución
df["region"].value_counts()
# Out:
# region
# Rioja                              2440
# Ribera del Duero                   1413
# Priorato                            686
# Toro                                300
# Vino de Espana                      263
#                                    ...
# Ribera del Gallego-Cinco Villas       1
# Monterrei                             1
# Jerez Cream                           1
# Condado de Huelva                     1
# Abona                                 1
# Name: count, Length: 76, dtype: int64

# %%
# solo las 5 regiones más comunes
df["region"].value_counts().head(5)
# Out:
# region
# Rioja               2440
# Ribera del Duero    1413
# Priorato             686
# Toro                 300
# Vino de Espana       263
# Name: count, dtype: int64

# %% [markdown]
# 8) Cambiar la región del segundo vino (fila 1) a  'Vino de España'

# %%
# solución
df.loc[1,"region"] = "Vino de España"
df
# Out:
#                     winery             wine  year  rating  num_reviews  \
# 0            Teso La Monja            Tinto  2013     4.9           58
# 1                   Artadi    Vina El Pison  2018     4.9           31
# 2             Vega Sicilia            Unico  2009     4.8         1793
# 3             Vega Sicilia            Unico  1999     4.8         1705
# 4             Vega Sicilia            Unico  1996     4.8         1309
# ...                    ...              ...   ...     ...          ...
# 7495               Contino          Reserva  2016     4.2          392
# 7496  Conreria d'Scala Dei    Les Brugueres  2018     4.2          390
# 7497           Mustiguillo  Finca Terrerazo  2017     4.2          390
# 7498           Matarromera     Gran Reserva  2011     4.2          389
# 7499              Sei Solo         Preludio  2016     4.2          388
#
#      country            region   price                  type  body  acidity
# 0     Espana              Toro  995.00              Toro Red   5.0      3.0
# 1     Espana    Vino de España  313.50           Tempranillo   4.0      2.0
# 2     Espana  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3     Espana  Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4     Espana  Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0
# ...      ...               ...     ...                   ...   ...      ...
# 7495  Espana             Rioja   19.98             Rioja Red   4.0      3.0
# 7496  Espana          Priorato   16.76           Priorat Red   4.0      3.0
# 7497  Espana      El Terrerazo   24.45                   Red   4.0      3.0
# 7498  Espana  Ribera del Duero   64.50  Ribera Del Duero Red   5.0      3.0
# 7499  Espana  Ribera del Duero   31.63  Ribera Del Duero Red   5.0      3.0
#
# [7500 rows x 11 columns]

# %% [markdown]
# 9) ¿Cuál es el valor máximo de la columna rating? (ayuda: aplicar la función max() tras el nombre de la columna)

# %%
# Solución pandas
df["rating"].max()
# Out:
# 4.9

# %%
# solución python estándar
max(df["rating"])
# Out:
# 4.9

# %%
df["body"].mean()
# Out:
# 4.158426788816932

# %%
# no!!!
sum(df["body"]) / len(df)
# Out:
# nan

# %% [markdown]
# 10.- Crear un nuevo dataframe df2 que solo tenga las columnas ```winery	wine	year price	type	body	acidity```. Grabar el resultado en un fichero excel "wines.xlsx"

# %%
# Solución
df2 = df[ ["winery", "wine", "year", "price", "type", "body", "acidity"]]

df2.to_excel("wines.xlsx",index=False)
